# %% [markdown]
# <a href="https://colab.research.google.com/github/pereisergio/Creating-Pipelines-for-Machine-Learning/blob/main/Pr%C3%A9_processamento_com_TensorFlow_Transform_(TFT).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Etapa 1: Instalação das bibliotecas

# %%
# !pip install tensorflow-transform

# %% [markdown]
# ## Etapa 2: Importação das bibliotecas

# %%
import tempfile
import pandas as pd
import tensorflow as tf
import tensorflow_transform as tft
import tensorflow_transform.beam.impl as tft_beam
from tensorflow_transform.tf_metadata import dataset_metadata, schema_utils

import apache_beam.io.iobase

from __future__ import print_function

print(tf.__version__)
print(tft.__version__)
# Out:
# 1.15.0
# 2.15.1

# %% [markdown]
# ## Etapa 3: Pré-processamento

# %% [markdown]
# ### Carregando a base de dados

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/TensorFlow 2.0/assets/pollution-small.csv')

# %%
dataset.head()
# Out:
#        Date   pm10    no2    so2   soot
# 0  1/1/2009  98.67  14.10  44.38  34.81
# 1  1/2/2009  52.33  14.10  29.75  33.06
# 2  1/3/2009  74.67  20.50  36.25  39.25
# 3  1/4/2009  72.00  17.30  46.44  34.38
# 4  1/5/2009  81.00  25.64  56.56  45.59

# %%
features = dataset.drop('Date', axis=1)
features.head()
# Out:
#     pm10    no2    so2   soot
# 0  98.67  14.10  44.38  34.81
# 1  52.33  14.10  29.75  33.06
# 2  74.67  20.50  36.25  39.25
# 3  72.00  17.30  46.44  34.38
# 4  81.00  25.64  56.56  45.59

# %% [markdown]
# ### Conversão da base de dados (dataframe) para dicionário

# %%
dict_features = list(features.to_dict('index').values())
dict_features[:2]
# Out:
# [{'pm10': 98.67, 'no2': 14.1, 'so2': 44.38, 'soot': 34.81},
#  {'pm10': 52.33, 'no2': 14.1, 'so2': 29.75, 'soot': 33.06}]

# %% [markdown]
# ### Definição dos metadados

# %%
# Definir o esquema do dataset
schema = {
    'no2': tf.io.FixedLenFeature([], tf.float32),
    'so2': tf.io.FixedLenFeature([], tf.float32),
    'pm10': tf.io.FixedLenFeature([], tf.float32),
    'soot': tf.io.FixedLenFeature([], tf.float32),
}

# Criar os metadados do dataset a partir do esquema
data_metadata = dataset_metadata.DatasetMetadata(schema_utils.schema_from_feature_spec(schema))

# %%
data_metadata
# Out:
# {'_schema': feature {
#   name: "no2"
#   type: FLOAT
#   presence {
#     min_fraction: 1.0
#   }
#   shape {
#   }
# }
# feature {
#   name: "pm10"
#   type: FLOAT
#   presence {
#     min_fraction: 1.0
#   }
#   shape {
#   }
# }
# feature {
#   name: "so2"
#   type: FLOAT
#   presence {
#     min_fraction: 1.0
#   }
#   shape {
#   }
# }
# feature {
#   name: "soot"
#   type: FLOAT
#   presence {
#     min_fraction: 1.0
#   }
#   shape {
#   }
# }
# , '_output_record_batches': True}

# %% [markdown]
# ## Etapa 4: Função para pré-processamento

# %%
def preprocessing_fn(inputs):
    no2 = inputs["no2"]
    pm10 = inputs["pm10"]
    so2 = inputs["so2"]
    soot = inputs["soot"]

    no2_normalized = no2 - tft.mean(no2)
    so2_normalized = so2 - tft.mean(so2)

    pm10_normalized = tft.scale_to_0_1(pm10)
    soot_normalized = tft.scale_by_min_max(soot)

    return {
        "no2_normalized": no2_normalized,
        "so2_normalized": so2_normalized,
        "pm10_normalized": pm10_normalized,
        "soot_normalized": soot_normalized
    }

# %% [markdown]
# ## Etapa 5: Unindo a codificação
#
# O Tensorflow Transform usa o **Apache Beam** como background para realizar as operações.
#
# Parâmetros a serem passados para a função:
#
#     dict_features - Nossa base de dados convertida para dicionário
#     data_metadata - Nossos metadados que criamos anteriormente
#     preprocessing_fn - Função de pré-processamento que fará as transformações coluna por coluna
#
#
# Abaixo temos a sintaxe usada pelo Apache Beam
#
# ```
# result = data_to_pass | where_to_pass_the_data
# ```
#
# Explicando cada um dos parâmetros:
#
# **result**  -> `transformed_dataset, transform_fn`
#
# **data_to_pass** -> `(dict_features, data_metadata)`
#
# **where_to_pass_the_data** -> `tft_beam.AnalyzeAndTransformDataset(preprocessing_fn)`
#
# ```
# transformed_dataset, transform_fn = ((dict_features, data_metadata) | tft_beam.AnalyzeAndTransformDataset(preprocessing_fn))
#
# ```
#
# Mais sobre essa sintaxe:
# https://beam.apache.org/documentation/programming-guide/#transforms
#
# LINKS:
# > Mais sobre o Apache Beam: https://beam.apache.org/

# %%
def data_transform():
    with tft_beam.Context(temp_dir = tempfile.mkdtemp()):
        transformed_dataset, transform_fn = ((dict_features, data_metadata) | tft_beam.AnalyzeAndTransformDataset(preprocessing_fn))

    transformed_data, transformed_metadata = transformed_dataset

    for i in range(len(transformed_data)):
        print("Initial: ", dict_features[i])
        print("Transformed: ", transformed_data[i])

# %%
data_transform()
# Out:
# WARNING:absl:You are passing instance dicts and DatasetMetadata to TFT which will not provide optimal performance. Consider following the TFT guide to upgrade to the TFXIO format (Apache Arrow RecordBatch).
# WARNING:absl:You are passing instance dicts and DatasetMetadata to TFT which will not provide optimal performance. Consider following the TFT guide to upgrade to the TFXIO format (Apache Arrow RecordBatch).
# WARNING:absl:You are outputting instance dicts from `TransformDataset` which will not provide optimal performance. Consider setting  `output_record_batches=True` to upgrade to the TFXIO format (Apache Arrow RecordBatch). Encoding functionality in this module works with both formats.
# WARNING:apache_beam.options.pipeline_options:Discarding unparseable args: ['/usr/local/lib/python3.10/dist-packages/colab_kernel_launcher.py', '-f', '/root/.local/share/jupyter/runtime/kernel-95bd3e4e-45aa-49c3-986f-4119a47b1b9b.json']
# Initial:  {'pm10': 98.67, 'no2': 14.1, 'so2': 44.38, 'soot': 34.81}
# Transformed:  {'no2_normalized': -18.577978134155273, 'pm10_normalized': 0.3407169580459595, 'so2_normalized': 28.85540771484375, 'soot_normalized': 0.283423513174057}
# Initial:  {'pm10': 52.33, 'no2': 14.1, 'so2': 29.75, 'soot': 33.06}
# Transformed:  {'no2_normalized': -18.577978134155273, 'pm10_normalized': 0.16963857412338257, 'so2_normalized': 14.225407600402832, 'soot_normalized': 0.26620757579803467}
# Initial:  {'pm10': 74.67, 'no2': 20.5, 'so2': 36.25, 'soot': 39.25}
# Transformed:  {'no2_normalized': -12.177978515625, 'pm10_normalized': 0.25211358070373535, 'so2_normalized': 20.725406646728516, 'soot_normalized': 0.32710281014442444}
# Initial:  {'pm10': 72.0, 'no2': 17.3, 'so2': 46.44, 'soot': 34.38}
# Transformed:  {'no2_normalized': -15.377979278564453, 'pm10_normalized': 0.24225644767284393, 'so2_normalized': 30.9154052734375, 'soot_normalized': 0.27919331192970276}
# Initial:  {'pm10': 81.0, 'no2': 25.64, 'so2': 56.56, 'soot': 45.59}
# Transformed:  {'no2_normalized': -7.0379791259765625, 'pm10_normalized': 0.275482714176178, 'so2_normalized': 41.03540802001953, 'soot_normalized': 0.38947367668151855}
# Initial:  {'pm10': 147.0, 'no2': 25.2, 'so2': 42.38, 'soot': 69.33}
# Transformed:  {'no2_normalized': -7.477977752685547, 'pm10_normalized': 0.5191420316696167, 'so2_normalized': 26.85540771484375, 'soot_normalized': 0.6230201721191406}
# Initial:  {'pm10': 185.0, 'no2': 21.91, 'so2': 71.69, 'soot': 84.06}
# Transformed:  {'no2_normalized': -10.76797866821289, 'pm10_normalized': 0.659430742263794, 'so2_normalized': 56.165409088134766, 'soot_normalized': 0.7679291367530823}
# Initial:  {'pm10': 148.67, 'no2': 25.09, 'so2': 51.75, 'soot': 74.41}
# Transformed:  {'no2_normalized': -7.587978363037109, 'pm10_normalized': 0.5253073573112488, 'so2_normalized': 36.225406646728516, 'soot_normalized': 0.6729956269264221}
# Initial:  {'pm10': 216.0, 'no2': 37.27, 'so2': 63.47, 'soot': 64.06}
# Transformed:  {'no2_normalized': 4.592021942138672, 'pm10_normalized': 0.7738767862319946, 'so2_normalized': 47.94540786743164, 'soot_normalized': 0.5711755752563477}
# Initial:  {'pm10': 135.67, 'no2': 23.18, 'so2': 63.13, 'soot': 58.94}
# Transformed:  {'no2_normalized': -9.497978210449219, 'pm10_normalized': 0.4773138165473938, 'so2_normalized': 47.60540771484375, 'soot_normalized': 0.5208066701889038}
# Initial:  {'pm10': 138.67, 'no2': 21.64, 'so2': 67.56, 'soot': 49.65}
# Transformed:  {'no2_normalized': -11.037979125976562, 'pm10_normalized': 0.488389253616333, 'so2_normalized': 52.035404205322266, 'soot_normalized': 0.42941465973854065}
# Initial:  {'pm10': 96.67, 'no2': 21.0, 'so2': 84.24, 'soot': 49.83}
# Transformed:  {'no2_normalized': -11.677978515625, 'pm10_normalized': 0.3333333432674408, 'so2_normalized': 68.71540832519531, 'soot_normalized': 0.43118545413017273}
# Initial:  {'pm10': 101.0, 'no2': 22.64, 'so2': 83.06, 'soot': 46.44}
# Transformed:  {'no2_normalized': -10.037979125976562, 'pm10_normalized': 0.34931889176368713, 'so2_normalized': 67.53540802001953, 'soot_normalized': 0.39783570170402527}
# Initial:  {'pm10': 129.33, 'no2': 25.42, 'so2': 78.11, 'soot': 55.53}
# Transformed:  {'no2_normalized': -7.257978439331055, 'pm10_normalized': 0.4539078176021576, 'so2_normalized': 62.58540725708008, 'soot_normalized': 0.48726019263267517}
# Initial:  {'pm10': 101.0, 'no2': 21.42, 'so2': 52.44, 'soot': 42.42}
# Transformed:  {'no2_normalized': -11.257978439331055, 'pm10_normalized': 0.34931889176368713, 'so2_normalized': 36.9154052734375, 'soot_normalized': 0.3582882285118103}
# Initial:  {'pm10': 83.67, 'no2': 47.08, 'so2': 44.94, 'soot': 39.84}
# Transformed:  {'no2_normalized': 14.402023315429688, 'pm10_normalized': 0.2853398323059082, 'so2_normalized': 29.4154052734375, 'soot_normalized': 0.3329070210456848}
# Initial:  {'pm10': 88.67, 'no2': 24.75, 'so2': 41.67, 'soot': 47.79}
# Transformed:  {'no2_normalized': -7.927978515625, 'pm10_normalized': 0.3037988841533661, 'so2_normalized': 26.145404815673828, 'soot_normalized': 0.4111165702342987}
# Initial:  {'pm10': 149.33, 'no2': 34.75, 'so2': 87.22, 'soot': 83.79}
# Transformed:  {'no2_normalized': 2.072021484375, 'pm10_normalized': 0.527743935585022, 'so2_normalized': 71.6954116821289, 'soot_normalized': 0.7652729749679565}
# Initial:  {'pm10': 41.0, 'no2': 32.08, 'so2': 52.89, 'soot': 46.42}
# Transformed:  {'no2_normalized': -0.5979766845703125, 'pm10_normalized': 0.12781038880348206, 'so2_normalized': 37.36540603637695, 'soot_normalized': 0.3976389467716217}
# Initial:  {'pm10': 46.33, 'no2': 26.5, 'so2': 36.5, 'soot': 27.76}
# Transformed:  {'no2_normalized': -6.177978515625, 'pm10_normalized': 0.14748772978782654, 'so2_normalized': 20.975406646728516, 'soot_normalized': 0.21406787633895874}
# Initial:  {'pm10': 26.67, 'no2': 19.67, 'so2': 28.59, 'soot': 16.28}
# Transformed:  {'no2_normalized': -13.007978439331055, 'pm10_normalized': 0.07490678876638412, 'so2_normalized': 13.065407752990723, 'soot_normalized': 0.10113133490085602}
# Initial:  {'pm10': 28.33, 'no2': 23.42, 'so2': 19.82, 'soot': 18.17}
# Transformed:  {'no2_normalized': -9.257978439331055, 'pm10_normalized': 0.08103518933057785, 'so2_normalized': 4.295407295227051, 'soot_normalized': 0.11972454190254211}
# Initial:  {'pm10': 40.67, 'no2': 25.58, 'so2': 17.94, 'soot': 28.56}
# Transformed:  {'no2_normalized': -7.097978591918945, 'pm10_normalized': 0.12659208476543427, 'so2_normalized': 2.415408134460449, 'soot_normalized': 0.22193801403045654}
# Initial:  {'pm10': 38.0, 'no2': 30.33, 'so2': 19.88, 'soot': 27.39}
# Transformed:  {'no2_normalized': -2.3479785919189453, 'pm10_normalized': 0.11673496663570404, 'so2_normalized': 4.355406761169434, 'soot_normalized': 0.210427924990654}
# Initial:  {'pm10': 25.0, 'no2': 25.33, 'so2': 16.88, 'soot': 16.17}
# Transformed:  {'no2_normalized': -7.347978591918945, 'pm10_normalized': 0.06874146312475204, 'so2_normalized': 1.3554067611694336, 'soot_normalized': 0.10004919022321701}
# Initial:  {'pm10': 48.67, 'no2': 32.5, 'so2': 20.35, 'soot': 29.11}
# Transformed:  {'no2_normalized': -0.177978515625, 'pm10_normalized': 0.15612654387950897, 'so2_normalized': 4.825407981872559, 'soot_normalized': 0.22734874486923218}
# Initial:  {'pm10': 35.67, 'no2': 27.42, 'so2': 25.47, 'soot': 22.28}
# Transformed:  {'no2_normalized': -5.257978439331055, 'pm10_normalized': 0.10813304036855698, 'so2_normalized': 9.945406913757324, 'soot_normalized': 0.16015741229057312}
# Initial:  {'pm10': 21.33, 'no2': 18.83, 'so2': 15.83, 'soot': 19.88}
# Transformed:  {'no2_normalized': -13.847978591918945, 'pm10_normalized': 0.055192526429891586, 'so2_normalized': 0.3054075241088867, 'soot_normalized': 0.13654696941375732}
# Initial:  {'pm10': 16.67, 'no2': 17.5, 'so2': 14.44, 'soot': 23.71}
# Transformed:  {'no2_normalized': -15.177978515625, 'pm10_normalized': 0.037988703697919846, 'so2_normalized': -1.0845928192138672, 'soot_normalized': 0.17422527074813843}
# Initial:  {'pm10': 29.33, 'no2': 15.42, 'so2': 15.28, 'soot': 27.61}
# Transformed:  {'no2_normalized': -17.257978439331055, 'pm10_normalized': 0.08472699671983719, 'so2_normalized': -0.24459266662597656, 'soot_normalized': 0.2125922292470932}
# Initial:  {'pm10': 31.33, 'no2': 17.0, 'so2': 17.39, 'soot': 24.33}
# Transformed:  {'no2_normalized': -15.677978515625, 'pm10_normalized': 0.09211061149835587, 'so2_normalized': 1.8654069900512695, 'soot_normalized': 0.18032464385032654}
# Initial:  {'pm10': 25.67, 'no2': 14.58, 'so2': 20.39, 'soot': 23.0}
# Transformed:  {'no2_normalized': -18.097978591918945, 'pm10_normalized': 0.07121498137712479, 'so2_normalized': 4.8654069900512695, 'soot_normalized': 0.16724053025245667}
# Initial:  {'pm10': 21.33, 'no2': 14.92, 'so2': 25.11, 'soot': 19.78}
# Transformed:  {'no2_normalized': -17.757978439331055, 'pm10_normalized': 0.055192526429891586, 'so2_normalized': 9.585408210754395, 'soot_normalized': 0.1355632096529007}
# Initial:  {'pm10': 19.67, 'no2': 10.42, 'so2': 20.88, 'soot': 19.79}
# Transformed:  {'no2_normalized': -22.257978439331055, 'pm10_normalized': 0.04906412586569786, 'so2_normalized': 5.355406761169434, 'soot_normalized': 0.13566158711910248}
# Initial:  {'pm10': 49.67, 'no2': 14.58, 'so2': 19.22, 'soot': 29.84}
# Transformed:  {'no2_normalized': -18.097978591918945, 'pm10_normalized': 0.1598183512687683, 'so2_normalized': 3.695406913757324, 'soot_normalized': 0.2345302551984787}
# Initial:  {'pm10': 62.0, 'no2': 30.08, 'so2': 27.06, 'soot': 48.0}
# Transformed:  {'no2_normalized': -2.5979785919189453, 'pm10_normalized': 0.20533835887908936, 'so2_normalized': 11.535407066345215, 'soot_normalized': 0.41318249702453613}
# Initial:  {'pm10': 30.67, 'no2': 27.67, 'so2': 21.61, 'soot': 35.68}
# Transformed:  {'no2_normalized': -5.007978439331055, 'pm10_normalized': 0.08967401832342148, 'so2_normalized': 6.0854082107543945, 'soot_normalized': 0.2919822931289673}
# Initial:  {'pm10': 29.33, 'no2': 19.58, 'so2': 16.39, 'soot': 23.11}
# Transformed:  {'no2_normalized': -13.097978591918945, 'pm10_normalized': 0.08472699671983719, 'so2_normalized': 0.8654069900512695, 'soot_normalized': 0.16832268238067627}
# Initial:  {'pm10': 27.0, 'no2': 16.17, 'so2': 15.11, 'soot': 23.79}
# Transformed:  {'no2_normalized': -16.507978439331055, 'pm10_normalized': 0.07612507790327072, 'so2_normalized': -0.4145927429199219, 'soot_normalized': 0.17501230537891388}
# Initial:  {'pm10': 12.67, 'no2': 14.5, 'so2': 11.5, 'soot': 15.94}
# Transformed:  {'no2_normalized': -18.177978515625, 'pm10_normalized': 0.023221472278237343, 'so2_normalized': -4.024592399597168, 'soot_normalized': 0.09778651595115662}
# Initial:  {'pm10': 30.33, 'no2': 25.0, 'so2': 17.67, 'soot': 30.05}
# Transformed:  {'no2_normalized': -7.677978515625, 'pm10_normalized': 0.08841880410909653, 'so2_normalized': 2.1454076766967773, 'soot_normalized': 0.23659615218639374}
# Initial:  {'pm10': 22.0, 'no2': 21.0, 'so2': 15.56, 'soot': 24.05}
# Transformed:  {'no2_normalized': -11.677978515625, 'pm10_normalized': 0.05766604095697403, 'so2_normalized': 0.03540802001953125, 'soot_normalized': 0.17757008969783783}
# Initial:  {'pm10': 18.33, 'no2': 17.82, 'so2': 14.33, 'soot': 17.21}
# Transformed:  {'no2_normalized': -14.857978820800781, 'pm10_normalized': 0.04411710426211357, 'so2_normalized': -1.1945924758911133, 'soot_normalized': 0.1102803647518158}
# Initial:  {'pm10': 21.33, 'no2': 17.55, 'so2': 17.35, 'soot': 17.83}
# Transformed:  {'no2_normalized': -15.127979278564453, 'pm10_normalized': 0.055192526429891586, 'so2_normalized': 1.8254079818725586, 'soot_normalized': 0.11637973040342331}
# Initial:  {'pm10': 24.0, 'no2': 15.91, 'so2': 13.76, 'soot': 16.94}
# Transformed:  {'no2_normalized': -16.76797866821289, 'pm10_normalized': 0.0650496557354927, 'so2_normalized': -1.764592170715332, 'soot_normalized': 0.10762420296669006}
# Initial:  {'pm10': 18.67, 'no2': 12.91, 'so2': 13.35, 'soot': 14.89}
# Transformed:  {'no2_normalized': -19.76797866821289, 'pm10_normalized': 0.04537231847643852, 'so2_normalized': -2.1745920181274414, 'soot_normalized': 0.08745696395635605}
# Initial:  {'pm10': 35.33, 'no2': 23.18, 'so2': 16.35, 'soot': 22.06}
# Transformed:  {'no2_normalized': -9.497978210449219, 'pm10_normalized': 0.10687784105539322, 'so2_normalized': 0.8254079818725586, 'soot_normalized': 0.1579931080341339}
# Initial:  {'pm10': 37.0, 'no2': 32.27, 'so2': 21.65, 'soot': 33.83}
# Transformed:  {'no2_normalized': -0.4079780578613281, 'pm10_normalized': 0.1130431517958641, 'so2_normalized': 6.1254072189331055, 'soot_normalized': 0.2737826108932495}
# Initial:  {'pm10': 33.33, 'no2': 19.33, 'so2': 16.28, 'soot': 25.68}
# Transformed:  {'no2_normalized': -13.347978591918945, 'pm10_normalized': 0.09949422627687454, 'so2_normalized': 0.7554082870483398, 'soot_normalized': 0.19360551238059998}
# Initial:  {'pm10': 20.0, 'no2': 13.67, 'so2': 18.56, 'soot': 19.53}
# Transformed:  {'no2_normalized': -19.007978439331055, 'pm10_normalized': 0.050282422453165054, 'so2_normalized': 3.035407066345215, 'soot_normalized': 0.13310378789901733}
# Initial:  {'pm10': 34.33, 'no2': 19.92, 'so2': 15.33, 'soot': 21.89}
# Transformed:  {'no2_normalized': -12.757978439331055, 'pm10_normalized': 0.10318603366613388, 'so2_normalized': -0.19459247589111328, 'soot_normalized': 0.1563207060098648}
# Initial:  {'pm10': 52.67, 'no2': 23.0, 'so2': 17.33, 'soot': 29.32}
# Transformed:  {'no2_normalized': -9.677978515625, 'pm10_normalized': 0.17089377343654633, 'so2_normalized': 1.8054075241088867, 'soot_normalized': 0.2294146567583084}
# Initial:  {'pm10': 75.33, 'no2': 23.17, 'so2': 13.78, 'soot': 35.26}
# Transformed:  {'no2_normalized': -9.507978439331055, 'pm10_normalized': 0.25455018877983093, 'so2_normalized': -1.7445926666259766, 'soot_normalized': 0.28785043954849243}
# Initial:  {'pm10': 114.33, 'no2': 39.58, 'so2': 31.72, 'soot': 53.37}
# Transformed:  {'no2_normalized': 6.9020233154296875, 'pm10_normalized': 0.3985306918621063, 'so2_normalized': 16.19540786743164, 'soot_normalized': 0.46601080894470215}
# Initial:  {'pm10': 123.0, 'no2': 39.08, 'so2': 35.06, 'soot': 52.26}
# Transformed:  {'no2_normalized': 6.4020233154296875, 'pm10_normalized': 0.4305386543273926, 'so2_normalized': 19.53540802001953, 'soot_normalized': 0.4550909698009491}
# Initial:  {'pm10': 89.0, 'no2': 29.92, 'so2': 23.06, 'soot': 39.63}
# Transformed:  {'no2_normalized': -2.7579784393310547, 'pm10_normalized': 0.3050171732902527, 'so2_normalized': 7.535407066345215, 'soot_normalized': 0.3308411240577698}
# Initial:  {'pm10': 72.33, 'no2': 31.0, 'so2': 23.72, 'soot': 37.89}
# Transformed:  {'no2_normalized': -1.677978515625, 'pm10_normalized': 0.24347475171089172, 'so2_normalized': 8.195406913757324, 'soot_normalized': 0.3137235641479492}
# Initial:  {'pm10': 44.33, 'no2': 29.58, 'so2': 23.94, 'soot': 35.47}
# Transformed:  {'no2_normalized': -3.0979785919189453, 'pm10_normalized': 0.14010411500930786, 'so2_normalized': 8.41540813446045, 'soot_normalized': 0.28991639614105225}
# Initial:  {'pm10': 36.67, 'no2': 31.5, 'so2': 20.72, 'soot': 35.47}
# Transformed:  {'no2_normalized': -1.177978515625, 'pm10_normalized': 0.11182485520839691, 'so2_normalized': 5.195406913757324, 'soot_normalized': 0.28991639614105225}
# Initial:  {'pm10': 75.5, 'no2': 35.13, 'so2': 28.65, 'soot': 48.47}
# Transformed:  {'no2_normalized': 2.4520225524902344, 'pm10_normalized': 0.255177766084671, 'so2_normalized': 13.125407218933105, 'soot_normalized': 0.4178062081336975}
# Initial:  {'pm10': 56.75, 'no2': 30.25, 'so2': 26.5, 'soot': 41.53}
# Transformed:  {'no2_normalized': -2.427978515625, 'pm10_normalized': 0.18595635890960693, 'so2_normalized': 10.975407600402832, 'soot_normalized': 0.34953269362449646}
# Initial:  {'pm10': 56.5, 'no2': 27.94, 'so2': 27.9, 'soot': 43.32}
# Transformed:  {'no2_normalized': -4.737977981567383, 'pm10_normalized': 0.1850334107875824, 'so2_normalized': 12.375407218933105, 'soot_normalized': 0.3671421408653259}
# Initial:  {'pm10': 38.5, 'no2': 16.75, 'so2': 19.0, 'soot': 26.11}
# Transformed:  {'no2_normalized': -15.927978515625, 'pm10_normalized': 0.11858087033033371, 'so2_normalized': 3.475407600402832, 'soot_normalized': 0.19783571362495422}
# Initial:  {'pm10': 22.75, 'no2': 10.56, 'so2': 15.75, 'soot': 21.11}
# Transformed:  {'no2_normalized': -22.117977142333984, 'pm10_normalized': 0.060434892773628235, 'so2_normalized': 0.22540760040283203, 'soot_normalized': 0.14864732325077057}
# Initial:  {'pm10': 33.0, 'no2': 17.81, 'so2': 15.8, 'soot': 23.79}
# Transformed:  {'no2_normalized': -14.867979049682617, 'pm10_normalized': 0.09827592223882675, 'so2_normalized': 0.2754077911376953, 'soot_normalized': 0.17501230537891388}
# Initial:  {'pm10': 29.83, 'no2': 15.81, 'so2': 11.35, 'soot': 18.21}
# Transformed:  {'no2_normalized': -16.867977142333984, 'pm10_normalized': 0.08657290041446686, 'so2_normalized': -4.174592018127441, 'soot_normalized': 0.12011804431676865}
# Initial:  {'pm10': 31.17, 'no2': 17.44, 'so2': 11.9, 'soot': 22.32}
# Transformed:  {'no2_normalized': -15.237977981567383, 'pm10_normalized': 0.09151992201805115, 'so2_normalized': -3.6245927810668945, 'soot_normalized': 0.16055090725421906}
# Initial:  {'pm10': 33.17, 'no2': 22.81, 'so2': 17.1, 'soot': 26.16}
# Transformed:  {'no2_normalized': -9.867979049682617, 'pm10_normalized': 0.09890352189540863, 'so2_normalized': 1.5754079818725586, 'soot_normalized': 0.19832758605480194}
# Initial:  {'pm10': 42.0, 'no2': 20.75, 'so2': 14.5, 'soot': 25.11}
# Transformed:  {'no2_normalized': -11.927978515625, 'pm10_normalized': 0.1315021961927414, 'so2_normalized': -1.024592399597168, 'soot_normalized': 0.18799804151058197}
# Initial:  {'pm10': 32.67, 'no2': 22.13, 'so2': 17.85, 'soot': 24.83}
# Transformed:  {'no2_normalized': -10.547979354858398, 'pm10_normalized': 0.09705761820077896, 'so2_normalized': 2.3254079818725586, 'soot_normalized': 0.18524347245693207}
# Initial:  {'pm10': 25.2, 'no2': 17.44, 'so2': 14.25, 'soot': 22.0}
# Transformed:  {'no2_normalized': -15.237977981567383, 'pm10_normalized': 0.06947982311248779, 'so2_normalized': -1.274592399597168, 'soot_normalized': 0.15740284323692322}
# Initial:  {'pm10': 25.67, 'no2': 18.13, 'so2': 16.2, 'soot': 20.22}
# Transformed:  {'no2_normalized': -14.547979354858398, 'pm10_normalized': 0.07121498137712479, 'so2_normalized': 0.6754083633422852, 'soot_normalized': 0.13989177346229553}
# Initial:  {'pm10': 42.0, 'no2': 18.06, 'so2': 14.0, 'soot': 21.83}
# Transformed:  {'no2_normalized': -14.617979049682617, 'pm10_normalized': 0.1315021961927414, 'so2_normalized': -1.524592399597168, 'soot_normalized': 0.1557304412126541}
# Initial:  {'pm10': 72.0, 'no2': 25.44, 'so2': 25.25, 'soot': 35.72}
# Transformed:  {'no2_normalized': -7.237977981567383, 'pm10_normalized': 0.24225644767284393, 'so2_normalized': 9.725407600402832, 'soot_normalized': 0.2923758029937744}
# Initial:  {'pm10': 38.83, 'no2': 18.69, 'so2': 16.55, 'soot': 20.33}
# Transformed:  {'no2_normalized': -13.987977981567383, 'pm10_normalized': 0.1197991669178009, 'so2_normalized': 1.025406837463379, 'soot_normalized': 0.14097392559051514}
# Initial:  {'pm10': 41.33, 'no2': 17.19, 'so2': 13.65, 'soot': 18.78}
# Transformed:  {'no2_normalized': -15.487977981567383, 'pm10_normalized': 0.12902869284152985, 'so2_normalized': -1.8745927810668945, 'soot_normalized': 0.12572553753852844}
# Initial:  {'pm10': 23.17, 'no2': 12.38, 'so2': 11.7, 'soot': 16.06}
# Transformed:  {'no2_normalized': -20.297977447509766, 'pm10_normalized': 0.06198545917868614, 'so2_normalized': -3.8245925903320312, 'soot_normalized': 0.0989670380949974}
# Initial:  {'pm10': 27.0, 'no2': 16.63, 'so2': 12.3, 'soot': 18.28}
# Transformed:  {'no2_normalized': -16.0479793548584, 'pm10_normalized': 0.07612507790327072, 'so2_normalized': -3.2245922088623047, 'soot_normalized': 0.12080669403076172}
# Initial:  {'pm10': 38.33, 'no2': 18.75, 'so2': 15.0, 'soot': 19.05}
# Transformed:  {'no2_normalized': -13.927978515625, 'pm10_normalized': 0.11795326322317123, 'so2_normalized': -0.524592399597168, 'soot_normalized': 0.12838169932365417}
# Initial:  {'pm10': 26.6, 'no2': 15.75, 'so2': 13.55, 'soot': 15.74}
# Transformed:  {'no2_normalized': -16.927978515625, 'pm10_normalized': 0.07464835792779922, 'so2_normalized': -1.9745922088623047, 'soot_normalized': 0.09581898152828217}
# Initial:  {'pm10': 31.0, 'no2': 14.94, 'so2': 12.4, 'soot': 16.42}
# Transformed:  {'no2_normalized': -17.737979888916016, 'pm10_normalized': 0.09089230746030807, 'so2_normalized': -3.1245927810668945, 'soot_normalized': 0.10250860452651978}
# Initial:  {'pm10': 28.0, 'no2': 20.0, 'so2': 14.15, 'soot': 17.79}
# Transformed:  {'no2_normalized': -12.677978515625, 'pm10_normalized': 0.07981688529253006, 'so2_normalized': -1.3745927810668945, 'soot_normalized': 0.11598623543977737}
# Initial:  {'pm10': 21.83, 'no2': 21.27, 'so2': 13.5, 'soot': 14.59}
# Transformed:  {'no2_normalized': -11.407978057861328, 'pm10_normalized': 0.057038433849811554, 'so2_normalized': -2.024592399597168, 'soot_normalized': 0.08450565487146378}
# Initial:  {'pm10': 28.83, 'no2': 18.57, 'so2': 12.6, 'soot': 17.0}
# Transformed:  {'no2_normalized': -14.107978820800781, 'pm10_normalized': 0.08288109302520752, 'so2_normalized': -2.9245920181274414, 'soot_normalized': 0.10821446031332016}
# Initial:  {'pm10': 34.67, 'no2': 26.33, 'so2': 17.4, 'soot': 21.24}
# Transformed:  {'no2_normalized': -6.347978591918945, 'pm10_normalized': 0.10444123297929764, 'so2_normalized': 1.8754072189331055, 'soot_normalized': 0.14992621541023254}
# Initial:  {'pm10': 34.17, 'no2': 28.0, 'so2': 17.95, 'soot': 20.88}
# Transformed:  {'no2_normalized': -4.677978515625, 'pm10_normalized': 0.10259532928466797, 'so2_normalized': 2.425408363342285, 'soot_normalized': 0.14638464152812958}
# Initial:  {'pm10': 27.33, 'no2': 22.6, 'so2': 14.85, 'soot': 16.71}
# Transformed:  {'no2_normalized': -10.077978134155273, 'pm10_normalized': 0.07734338194131851, 'so2_normalized': -0.6745920181274414, 'soot_normalized': 0.10536152124404907}
# Initial:  {'pm10': 47.83, 'no2': 13.29, 'so2': 10.95, 'soot': 15.88}
# Transformed:  {'no2_normalized': -19.387977600097656, 'pm10_normalized': 0.15302544832229614, 'so2_normalized': -4.574592590332031, 'soot_normalized': 0.09719625860452652}
# Initial:  {'pm10': 29.83, 'no2': 19.57, 'so2': 12.05, 'soot': 16.82}
# Transformed:  {'no2_normalized': -13.107978820800781, 'pm10_normalized': 0.08657290041446686, 'so2_normalized': -3.4745922088623047, 'soot_normalized': 0.10644367337226868}
# Initial:  {'pm10': 34.2, 'no2': 19.21, 'so2': 9.9, 'soot': 19.44}
# Transformed:  {'no2_normalized': -13.467979431152344, 'pm10_normalized': 0.10270609706640244, 'so2_normalized': -5.6245927810668945, 'soot_normalized': 0.1322184056043625}
# Initial:  {'pm10': 60.83, 'no2': 19.47, 'so2': 12.55, 'soot': 24.65}
# Transformed:  {'no2_normalized': -13.207979202270508, 'pm10_normalized': 0.20101894438266754, 'so2_normalized': -2.9745922088623047, 'soot_normalized': 0.18347269296646118}
# Initial:  {'pm10': 39.17, 'no2': 17.46, 'so2': 10.95, 'soot': 20.5}
# Transformed:  {'no2_normalized': -15.217979431152344, 'pm10_normalized': 0.12105437368154526, 'so2_normalized': -4.574592590332031, 'soot_normalized': 0.14264632761478424}
# Initial:  {'pm10': 27.5, 'no2': 16.07, 'so2': 10.3, 'soot': 16.27}
# Transformed:  {'no2_normalized': -16.60797882080078, 'pm10_normalized': 0.07797098159790039, 'so2_normalized': -5.224592208862305, 'soot_normalized': 0.10103295743465424}
# Initial:  {'pm10': 35.33, 'no2': 20.93, 'so2': 11.7, 'soot': 21.27}
# Transformed:  {'no2_normalized': -11.747978210449219, 'pm10_normalized': 0.10687784105539322, 'so2_normalized': -3.8245925903320312, 'soot_normalized': 0.1502213478088379}
# Initial:  {'pm10': 51.83, 'no2': 31.07, 'so2': 12.45, 'soot': 29.2}
# Transformed:  {'no2_normalized': -1.6079788208007812, 'pm10_normalized': 0.1677926778793335, 'so2_normalized': -3.0745925903320312, 'soot_normalized': 0.22823414206504822}
# Initial:  {'pm10': 53.6, 'no2': 29.0, 'so2': 14.1, 'soot': 27.6}
# Transformed:  {'no2_normalized': -3.677978515625, 'pm10_normalized': 0.17432716488838196, 'so2_normalized': -1.4245920181274414, 'soot_normalized': 0.21249385178089142}
# Initial:  {'pm10': 48.0, 'no2': 30.36, 'so2': 12.9, 'soot': 27.63}
# Transformed:  {'no2_normalized': -2.3179779052734375, 'pm10_normalized': 0.15365304052829742, 'so2_normalized': -2.6245927810668945, 'soot_normalized': 0.21278896927833557}
# Initial:  {'pm10': 39.0, 'no2': 30.8, 'so2': 11.25, 'soot': 32.88}
# Transformed:  {'no2_normalized': -1.8779792785644531, 'pm10_normalized': 0.12042677402496338, 'so2_normalized': -4.274592399597168, 'soot_normalized': 0.264436811208725}
# Initial:  {'pm10': 65.8, 'no2': 34.33, 'so2': 14.15, 'soot': 42.71}
# Transformed:  {'no2_normalized': 1.6520233154296875, 'pm10_normalized': 0.21936723589897156, 'so2_normalized': -1.3745927810668945, 'soot_normalized': 0.3611411452293396}
# Initial:  {'pm10': 61.4, 'no2': 38.6, 'so2': 19.2, 'soot': 42.67}
# Transformed:  {'no2_normalized': 5.922019958496094, 'pm10_normalized': 0.2031232714653015, 'so2_normalized': 3.675408363342285, 'soot_normalized': 0.36074763536453247}
# Initial:  {'pm10': 39.17, 'no2': 18.0, 'so2': 10.3, 'soot': 18.61}
# Transformed:  {'no2_normalized': -14.677978515625, 'pm10_normalized': 0.12105437368154526, 'so2_normalized': -5.224592208862305, 'soot_normalized': 0.12405312806367874}
# Initial:  {'pm10': 35.33, 'no2': 15.27, 'so2': 9.8, 'soot': 12.89}
# Transformed:  {'no2_normalized': -17.407978057861328, 'pm10_normalized': 0.10687784105539322, 'so2_normalized': -5.724592208862305, 'soot_normalized': 0.06778160482645035}
# Initial:  {'pm10': 44.0, 'no2': 15.36, 'so2': 8.8, 'soot': 13.94}
# Transformed:  {'no2_normalized': -17.317977905273438, 'pm10_normalized': 0.13888581097126007, 'so2_normalized': -6.724592208862305, 'soot_normalized': 0.07811115682125092}
# Initial:  {'pm10': 32.83, 'no2': 22.57, 'so2': 11.6, 'soot': 24.76}
# Transformed:  {'no2_normalized': -10.107978820800781, 'pm10_normalized': 0.09764832258224487, 'so2_normalized': -3.9245920181274414, 'soot_normalized': 0.1845548450946808}
# Initial:  {'pm10': 40.83, 'no2': 25.5, 'so2': 12.3, 'soot': 29.24}
# Transformed:  {'no2_normalized': -7.177978515625, 'pm10_normalized': 0.12718278169631958, 'so2_normalized': -3.2245922088623047, 'soot_normalized': 0.22862763702869415}
# Initial:  {'pm10': 45.67, 'no2': 39.69, 'so2': 14.7, 'soot': 42.74}
# Transformed:  {'no2_normalized': 7.012020111083984, 'pm10_normalized': 0.14505112171173096, 'so2_normalized': -0.8245925903320312, 'soot_normalized': 0.36143630743026733}
# Initial:  {'pm10': 27.67, 'no2': 24.13, 'so2': 10.5, 'soot': 17.84}
# Transformed:  {'no2_normalized': -8.547979354858398, 'pm10_normalized': 0.07859859615564346, 'so2_normalized': -5.024592399597168, 'soot_normalized': 0.11647810786962509}
# Initial:  {'pm10': 24.67, 'no2': 22.94, 'so2': 9.45, 'soot': 17.11}
# Transformed:  {'no2_normalized': -9.737977981567383, 'pm10_normalized': 0.06752317398786545, 'so2_normalized': -6.074592590332031, 'soot_normalized': 0.10929661244153976}
# Initial:  {'pm10': 34.0, 'no2': 23.31, 'so2': 9.55, 'soot': 23.05}
# Transformed:  {'no2_normalized': -9.367979049682617, 'pm10_normalized': 0.10196772962808609, 'so2_normalized': -5.974592208862305, 'soot_normalized': 0.16773240268230438}
# Initial:  {'pm10': 28.17, 'no2': 23.75, 'so2': 9.2, 'soot': 19.68}
# Transformed:  {'no2_normalized': -8.927978515625, 'pm10_normalized': 0.08044449985027313, 'so2_normalized': -6.324592590332031, 'soot_normalized': 0.13457943499088287}
# Initial:  {'pm10': 34.33, 'no2': 22.94, 'so2': 9.1, 'soot': 19.05}
# Transformed:  {'no2_normalized': -9.737977981567383, 'pm10_normalized': 0.10318603366613388, 'so2_normalized': -6.424592018127441, 'soot_normalized': 0.12838169932365417}
# Initial:  {'pm10': 29.67, 'no2': 20.5, 'so2': 8.75, 'soot': 18.89}
# Transformed:  {'no2_normalized': -12.177978515625, 'pm10_normalized': 0.08598221093416214, 'so2_normalized': -6.774592399597168, 'soot_normalized': 0.12680765986442566}
# Initial:  {'pm10': 19.75, 'no2': 20.5, 'so2': 8.45, 'soot': 17.05}
# Transformed:  {'no2_normalized': -12.177978515625, 'pm10_normalized': 0.04935947060585022, 'so2_normalized': -7.074592590332031, 'soot_normalized': 0.10870633274316788}
# Initial:  {'pm10': 28.83, 'no2': 28.81, 'so2': 9.5, 'soot': 28.32}
# Transformed:  {'no2_normalized': -3.867979049682617, 'pm10_normalized': 0.08288109302520752, 'so2_normalized': -6.024592399597168, 'soot_normalized': 0.21957696974277496}
# Initial:  {'pm10': 39.0, 'no2': 28.13, 'so2': 11.3, 'soot': 27.16}
# Transformed:  {'no2_normalized': -4.547979354858398, 'pm10_normalized': 0.12042677402496338, 'so2_normalized': -4.224592208862305, 'soot_normalized': 0.2081652730703354}
# Initial:  {'pm10': 24.5, 'no2': 18.38, 'so2': 8.85, 'soot': 13.47}
# Transformed:  {'no2_normalized': -14.297979354858398, 'pm10_normalized': 0.06689555943012238, 'so2_normalized': -6.674592018127441, 'soot_normalized': 0.07348746061325073}
# Initial:  {'pm10': 23.33, 'no2': 17.75, 'so2': 7.55, 'soot': 14.42}
# Transformed:  {'no2_normalized': -14.927978515625, 'pm10_normalized': 0.06257614493370056, 'so2_normalized': -7.974592208862305, 'soot_normalized': 0.08283325284719467}
# Initial:  {'pm10': 24.2, 'no2': 19.38, 'so2': 9.55, 'soot': 16.95}
# Transformed:  {'no2_normalized': -13.297979354858398, 'pm10_normalized': 0.06578801572322845, 'so2_normalized': -5.974592208862305, 'soot_normalized': 0.10772258043289185}
# Initial:  {'pm10': 24.2, 'no2': 23.93, 'so2': 9.05, 'soot': 22.95}
# Transformed:  {'no2_normalized': -8.747978210449219, 'pm10_normalized': 0.06578801572322845, 'so2_normalized': -6.474592208862305, 'soot_normalized': 0.16674865782260895}
# Initial:  {'pm10': 17.6, 'no2': 21.2, 'so2': 8.85, 'soot': 19.26}
# Transformed:  {'no2_normalized': -11.477977752685547, 'pm10_normalized': 0.04142208769917488, 'so2_normalized': -6.674592018127441, 'soot_normalized': 0.1304476112127304}
# Initial:  {'pm10': 28.0, 'no2': 15.5, 'so2': 7.9, 'soot': 18.63}
# Transformed:  {'no2_normalized': -17.177978515625, 'pm10_normalized': 0.07981688529253006, 'so2_normalized': -7.624592304229736, 'soot_normalized': 0.12424986809492111}
# Initial:  {'pm10': 25.67, 'no2': 11.69, 'so2': 7.85, 'soot': 16.68}
# Transformed:  {'no2_normalized': -20.987979888916016, 'pm10_normalized': 0.07121498137712479, 'so2_normalized': -7.6745924949646, 'soot_normalized': 0.10506640374660492}
# Initial:  {'pm10': 37.0, 'no2': 19.94, 'so2': 9.3, 'soot': 21.74}
# Transformed:  {'no2_normalized': -12.737977981567383, 'pm10_normalized': 0.1130431517958641, 'so2_normalized': -6.224592208862305, 'soot_normalized': 0.15484505891799927}
# Initial:  {'pm10': 33.67, 'no2': 22.75, 'so2': 10.1, 'soot': 24.89}
# Transformed:  {'no2_normalized': -9.927978515625, 'pm10_normalized': 0.1007494255900383, 'so2_normalized': -5.424592018127441, 'soot_normalized': 0.18583373725414276}
# Initial:  {'pm10': 25.17, 'no2': 18.44, 'so2': 8.6, 'soot': 20.05}
# Transformed:  {'no2_normalized': -14.237977981567383, 'pm10_normalized': 0.06936907768249512, 'so2_normalized': -6.924592018127441, 'soot_normalized': 0.13821937143802643}
# Initial:  {'pm10': 22.0, 'no2': 21.0, 'so2': 8.8, 'soot': 21.05}
# Transformed:  {'no2_normalized': -11.677978515625, 'pm10_normalized': 0.05766604095697403, 'so2_normalized': -6.724592208862305, 'soot_normalized': 0.14805704355239868}
# Initial:  {'pm10': 23.0, 'no2': 21.75, 'so2': 8.5, 'soot': 21.74}
# Transformed:  {'no2_normalized': -10.927978515625, 'pm10_normalized': 0.06135784462094307, 'so2_normalized': -7.024592399597168, 'soot_normalized': 0.15484505891799927}
# Initial:  {'pm10': 26.67, 'no2': 29.63, 'so2': 10.85, 'soot': 30.63}
# Transformed:  {'no2_normalized': -3.0479793548583984, 'pm10_normalized': 0.07490678876638412, 'so2_normalized': -4.674592018127441, 'soot_normalized': 0.24230200052261353}
# Initial:  {'pm10': 35.75, 'no2': 33.25, 'so2': 13.4, 'soot': 37.0}
# Transformed:  {'no2_normalized': 0.572021484375, 'pm10_normalized': 0.10842839628458023, 'so2_normalized': -2.1245927810668945, 'soot_normalized': 0.3049680292606354}
# Initial:  {'pm10': 31.0, 'no2': 30.13, 'so2': 11.55, 'soot': 30.42}
# Transformed:  {'no2_normalized': -2.5479793548583984, 'pm10_normalized': 0.09089230746030807, 'so2_normalized': -3.9745922088623047, 'soot_normalized': 0.2402361035346985}
# Initial:  {'pm10': 36.5, 'no2': 30.31, 'so2': 17.4, 'soot': 27.63}
# Transformed:  {'no2_normalized': -2.367979049682617, 'pm10_normalized': 0.11119724810123444, 'so2_normalized': 1.8754072189331055, 'soot_normalized': 0.21278896927833557}
# Initial:  {'pm10': 31.5, 'no2': 26.13, 'so2': 10.65, 'soot': 22.37}
# Transformed:  {'no2_normalized': -6.547979354858398, 'pm10_normalized': 0.09273821115493774, 'so2_normalized': -4.8745927810668945, 'soot_normalized': 0.16104279458522797}
# Initial:  {'pm10': 20.17, 'no2': 17.25, 'so2': 9.1, 'soot': 18.21}
# Transformed:  {'no2_normalized': -15.427978515625, 'pm10_normalized': 0.05091002956032753, 'so2_normalized': -6.424592018127441, 'soot_normalized': 0.12011804431676865}
# Initial:  {'pm10': 32.5, 'no2': 22.44, 'so2': 9.35, 'soot': 22.95}
# Transformed:  {'no2_normalized': -10.237977981567383, 'pm10_normalized': 0.09643001854419708, 'so2_normalized': -6.174592018127441, 'soot_normalized': 0.16674865782260895}
# Initial:  {'pm10': 47.67, 'no2': 29.81, 'so2': 12.95, 'soot': 28.84}
# Transformed:  {'no2_normalized': -2.867979049682617, 'pm10_normalized': 0.15243473649024963, 'so2_normalized': -2.5745925903320312, 'soot_normalized': 0.22469256818294525}
# Initial:  {'pm10': 40.17, 'no2': 28.81, 'so2': 13.3, 'soot': 25.42}
# Transformed:  {'no2_normalized': -3.867979049682617, 'pm10_normalized': 0.1247461810708046, 'so2_normalized': -2.2245922088623047, 'soot_normalized': 0.19104771316051483}
# Initial:  {'pm10': 44.17, 'no2': 27.06, 'so2': 11.9, 'soot': 25.37}
# Transformed:  {'no2_normalized': -5.617979049682617, 'pm10_normalized': 0.13951341807842255, 'so2_normalized': -3.6245927810668945, 'soot_normalized': 0.19055584073066711}
# Initial:  {'pm10': 38.17, 'no2': 25.19, 'so2': 11.8, 'soot': 23.32}
# Transformed:  {'no2_normalized': -7.487977981567383, 'pm10_normalized': 0.11736256629228592, 'so2_normalized': -3.7245922088623047, 'soot_normalized': 0.1703885793685913}
# Initial:  {'pm10': 34.17, 'no2': 19.07, 'so2': 10.25, 'soot': 21.11}
# Transformed:  {'no2_normalized': -13.607978820800781, 'pm10_normalized': 0.10259532928466797, 'so2_normalized': -5.274592399597168, 'soot_normalized': 0.14864732325077057}
# Initial:  {'pm10': 31.17, 'no2': 16.4, 'so2': 9.45, 'soot': 16.94}
# Transformed:  {'no2_normalized': -16.277978897094727, 'pm10_normalized': 0.09151992201805115, 'so2_normalized': -6.074592590332031, 'soot_normalized': 0.10762420296669006}
# Initial:  {'pm10': 35.67, 'no2': 25.67, 'so2': 10.0, 'soot': 20.78}
# Transformed:  {'no2_normalized': -7.007978439331055, 'pm10_normalized': 0.10813304036855698, 'so2_normalized': -5.524592399597168, 'soot_normalized': 0.14540089666843414}
# Initial:  {'pm10': 43.17, 'no2': 34.6, 'so2': 13.5, 'soot': 27.78}
# Transformed:  {'no2_normalized': 1.9220199584960938, 'pm10_normalized': 0.1358216106891632, 'so2_normalized': -2.024592399597168, 'soot_normalized': 0.2142646312713623}
# Initial:  {'pm10': 23.67, 'no2': 23.27, 'so2': 9.75, 'soot': 16.89}
# Transformed:  {'no2_normalized': -9.407978057861328, 'pm10_normalized': 0.06383135914802551, 'so2_normalized': -5.774592399597168, 'soot_normalized': 0.10713230818510056}
# Initial:  {'pm10': 29.5, 'no2': 25.0, 'so2': 10.45, 'soot': 23.72}
# Transformed:  {'no2_normalized': -7.677978515625, 'pm10_normalized': 0.08535459637641907, 'so2_normalized': -5.074592590332031, 'soot_normalized': 0.1743236482143402}
# Initial:  {'pm10': 39.17, 'no2': 30.6, 'so2': 10.4, 'soot': 25.89}
# Transformed:  {'no2_normalized': -2.0779781341552734, 'pm10_normalized': 0.12105437368154526, 'so2_normalized': -5.1245927810668945, 'soot_normalized': 0.19567140936851501}
# Initial:  {'pm10': 35.0, 'no2': 29.07, 'so2': 11.55, 'soot': 22.16}
# Transformed:  {'no2_normalized': -3.6079788208007812, 'pm10_normalized': 0.10565953701734543, 'so2_normalized': -3.9745922088623047, 'soot_normalized': 0.15897688269615173}
# Initial:  {'pm10': 28.0, 'no2': 20.33, 'so2': 9.55, 'soot': 17.42}
# Transformed:  {'no2_normalized': -12.347978591918945, 'pm10_normalized': 0.07981688529253006, 'so2_normalized': -5.974592208862305, 'soot_normalized': 0.11234628409147263}
# Initial:  {'pm10': 20.5, 'no2': 18.0, 'so2': 8.9, 'soot': 16.33}
# Transformed:  {'no2_normalized': -14.677978515625, 'pm10_normalized': 0.052128326147794724, 'so2_normalized': -6.6245927810668945, 'soot_normalized': 0.10162321478128433}
# Initial:  {'pm10': 21.17, 'no2': 19.47, 'so2': 9.45, 'soot': 17.11}
# Transformed:  {'no2_normalized': -13.207979202270508, 'pm10_normalized': 0.05460184067487717, 'so2_normalized': -6.074592590332031, 'soot_normalized': 0.10929661244153976}
# Initial:  {'pm10': 23.33, 'no2': 17.67, 'so2': 9.7, 'soot': 17.61}
# Transformed:  {'no2_normalized': -15.007978439331055, 'pm10_normalized': 0.06257614493370056, 'so2_normalized': -5.824592590332031, 'soot_normalized': 0.11421544849872589}
# Initial:  {'pm10': 28.33, 'no2': 19.73, 'so2': 10.5, 'soot': 17.67}
# Transformed:  {'no2_normalized': -12.947978973388672, 'pm10_normalized': 0.08103518933057785, 'so2_normalized': -5.024592399597168, 'soot_normalized': 0.11480570584535599}
# Initial:  {'pm10': 28.5, 'no2': 22.33, 'so2': 9.1, 'soot': 16.42}
# Transformed:  {'no2_normalized': -10.347978591918945, 'pm10_normalized': 0.08166278898715973, 'so2_normalized': -6.424592018127441, 'soot_normalized': 0.10250860452651978}
# Initial:  {'pm10': 21.67, 'no2': 23.25, 'so2': 9.15, 'soot': 15.79}
# Transformed:  {'no2_normalized': -9.427978515625, 'pm10_normalized': 0.056447744369506836, 'so2_normalized': -6.3745927810668945, 'soot_normalized': 0.09631086885929108}
# Initial:  {'pm10': 26.17, 'no2': 23.87, 'so2': 9.7, 'soot': 17.21}
# Transformed:  {'no2_normalized': -8.807977676391602, 'pm10_normalized': 0.07306088507175446, 'so2_normalized': -5.824592590332031, 'soot_normalized': 0.1102803647518158}
# Initial:  {'pm10': 25.67, 'no2': 24.56, 'so2': 10.0, 'soot': 20.21}
# Transformed:  {'no2_normalized': -8.117979049682617, 'pm10_normalized': 0.07121498137712479, 'so2_normalized': -5.524592399597168, 'soot_normalized': 0.13979339599609375}
# Initial:  {'pm10': 23.67, 'no2': 26.5, 'so2': 9.35, 'soot': 17.26}
# Transformed:  {'no2_normalized': -6.177978515625, 'pm10_normalized': 0.06383135914802551, 'so2_normalized': -6.174592018127441, 'soot_normalized': 0.1107722595334053}
# Initial:  {'pm10': 24.17, 'no2': 25.0, 'so2': 9.3, 'soot': 20.42}
# Transformed:  {'no2_normalized': -7.677978515625, 'pm10_normalized': 0.06567727029323578, 'so2_normalized': -6.224592208862305, 'soot_normalized': 0.14185932278633118}
# Initial:  {'pm10': 27.5, 'no2': 24.5, 'so2': 9.75, 'soot': 14.89}
# Transformed:  {'no2_normalized': -8.177978515625, 'pm10_normalized': 0.07797098159790039, 'so2_normalized': -5.774592399597168, 'soot_normalized': 0.08745696395635605}
# Initial:  {'pm10': 25.83, 'no2': 25.27, 'so2': 9.85, 'soot': 23.95}
# Transformed:  {'no2_normalized': -7.407978057861328, 'pm10_normalized': 0.0718056708574295, 'so2_normalized': -5.674592018127441, 'soot_normalized': 0.1765863299369812}
# Initial:  {'pm10': 38.5, 'no2': 29.94, 'so2': 11.9, 'soot': 25.16}
# Transformed:  {'no2_normalized': -2.737977981567383, 'pm10_normalized': 0.11858087033033371, 'so2_normalized': -3.6245927810668945, 'soot_normalized': 0.1884899139404297}
# Initial:  {'pm10': 31.83, 'no2': 26.38, 'so2': 10.85, 'soot': 20.79}
# Transformed:  {'no2_normalized': -6.297979354858398, 'pm10_normalized': 0.09395651519298553, 'so2_normalized': -4.674592018127441, 'soot_normalized': 0.14549927413463593}
# Initial:  {'pm10': 30.8, 'no2': 20.69, 'so2': 9.6, 'soot': 16.11}
# Transformed:  {'no2_normalized': -11.987977981567383, 'pm10_normalized': 0.09015394002199173, 'so2_normalized': -5.924592018127441, 'soot_normalized': 0.09945893287658691}
# Initial:  {'pm10': 18.5, 'no2': 21.69, 'so2': 9.95, 'soot': 17.79}
# Transformed:  {'no2_normalized': -10.987977981567383, 'pm10_normalized': 0.04474471136927605, 'so2_normalized': -5.574592590332031, 'soot_normalized': 0.11598623543977737}
# Initial:  {'pm10': 24.5, 'no2': 24.75, 'so2': 10.45, 'soot': 20.32}
# Transformed:  {'no2_normalized': -7.927978515625, 'pm10_normalized': 0.06689555943012238, 'so2_normalized': -5.074592590332031, 'soot_normalized': 0.14087554812431335}
# Initial:  {'pm10': 23.67, 'no2': 27.88, 'so2': 11.75, 'soot': 22.53}
# Transformed:  {'no2_normalized': -4.797979354858398, 'pm10_normalized': 0.06383135914802551, 'so2_normalized': -3.774592399597168, 'soot_normalized': 0.16261683404445648}
# Initial:  {'pm10': 25.67, 'no2': 29.0, 'so2': 12.4, 'soot': 20.89}
# Transformed:  {'no2_normalized': -3.677978515625, 'pm10_normalized': 0.07121498137712479, 'so2_normalized': -3.1245927810668945, 'soot_normalized': 0.14648301899433136}
# Initial:  {'pm10': 25.5, 'no2': 26.94, 'so2': 12.65, 'soot': 21.11}
# Transformed:  {'no2_normalized': -5.737977981567383, 'pm10_normalized': 0.07058736681938171, 'so2_normalized': -2.8745927810668945, 'soot_normalized': 0.14864732325077057}
# Initial:  {'pm10': 16.67, 'no2': 23.5, 'so2': 10.75, 'soot': 19.11}
# Transformed:  {'no2_normalized': -9.177978515625, 'pm10_normalized': 0.037988703697919846, 'so2_normalized': -4.774592399597168, 'soot_normalized': 0.12897196412086487}
# Initial:  {'pm10': 31.5, 'no2': 28.31, 'so2': 12.7, 'soot': 19.44}
# Transformed:  {'no2_normalized': -4.367979049682617, 'pm10_normalized': 0.09273821115493774, 'so2_normalized': -2.8245925903320312, 'soot_normalized': 0.1322184056043625}
# Initial:  {'pm10': 31.67, 'no2': 25.73, 'so2': 10.85, 'soot': 19.65}
# Transformed:  {'no2_normalized': -6.947978973388672, 'pm10_normalized': 0.09336582571268082, 'so2_normalized': -4.674592018127441, 'soot_normalized': 0.13428430259227753}
# Initial:  {'pm10': 26.67, 'no2': 20.07, 'so2': 9.2, 'soot': 18.0}
# Transformed:  {'no2_normalized': -12.607978820800781, 'pm10_normalized': 0.07490678876638412, 'so2_normalized': -6.324592590332031, 'soot_normalized': 0.11805213987827301}
# Initial:  {'pm10': 10.0, 'no2': 19.87, 'so2': 9.65, 'soot': 16.41}
# Transformed:  {'no2_normalized': -12.807977676391602, 'pm10_normalized': 0.013364343903958797, 'so2_normalized': -5.8745927810668945, 'soot_normalized': 0.102410227060318}
# Initial:  {'pm10': 11.83, 'no2': 20.73, 'so2': 9.8, 'soot': 18.56}
# Transformed:  {'no2_normalized': -11.947978973388672, 'pm10_normalized': 0.020120352506637573, 'so2_normalized': -5.724592208862305, 'soot_normalized': 0.12356123328208923}
# Initial:  {'pm10': 23.67, 'no2': 25.0, 'so2': 11.9, 'soot': 17.67}
# Transformed:  {'no2_normalized': -7.677978515625, 'pm10_normalized': 0.06383135914802551, 'so2_normalized': -3.6245927810668945, 'soot_normalized': 0.11480570584535599}
# Initial:  {'pm10': 20.33, 'no2': 24.33, 'so2': 10.85, 'soot': 16.72}
# Transformed:  {'no2_normalized': -8.347978591918945, 'pm10_normalized': 0.05150071904063225, 'so2_normalized': -4.674592018127441, 'soot_normalized': 0.10545990616083145}
# Initial:  {'pm10': 18.67, 'no2': 21.73, 'so2': 11.0, 'soot': 13.61}
# Transformed:  {'no2_normalized': -10.947978973388672, 'pm10_normalized': 0.04537231847643852, 'so2_normalized': -4.524592399597168, 'soot_normalized': 0.07486473023891449}
# Initial:  {'pm10': 20.33, 'no2': 22.87, 'so2': 11.5, 'soot': 18.78}
# Transformed:  {'no2_normalized': -9.807977676391602, 'pm10_normalized': 0.05150071904063225, 'so2_normalized': -4.024592399597168, 'soot_normalized': 0.12572553753852844}
# Initial:  {'pm10': 32.5, 'no2': 22.0, 'so2': 10.45, 'soot': 20.0}
# Transformed:  {'no2_normalized': -10.677978515625, 'pm10_normalized': 0.09643001854419708, 'so2_normalized': -5.074592590332031, 'soot_normalized': 0.1377274990081787}
# Initial:  {'pm10': 33.25, 'no2': 24.93, 'so2': 10.8, 'soot': 22.56}
# Transformed:  {'no2_normalized': -7.747978210449219, 'pm10_normalized': 0.09919887781143188, 'so2_normalized': -4.724592208862305, 'soot_normalized': 0.16291195154190063}
# Initial:  {'pm10': 26.5, 'no2': 22.6, 'so2': 10.5, 'soot': 19.11}
# Transformed:  {'no2_normalized': -10.077978134155273, 'pm10_normalized': 0.07427917420864105, 'so2_normalized': -5.024592399597168, 'soot_normalized': 0.12897196412086487}
# Initial:  {'pm10': 29.25, 'no2': 26.6, 'so2': 10.3, 'soot': 23.28}
# Transformed:  {'no2_normalized': -6.077978134155273, 'pm10_normalized': 0.08443164080381393, 'so2_normalized': -5.224592208862305, 'soot_normalized': 0.16999508440494537}
# Initial:  {'pm10': 33.9, 'no2': 25.69, 'so2': 10.28, 'soot': 26.33}
# Transformed:  {'no2_normalized': -6.987977981567383, 'pm10_normalized': 0.10159855335950851, 'so2_normalized': -5.244592666625977, 'soot_normalized': 0.20000000298023224}
# Initial:  {'pm10': 40.03, 'no2': 28.76, 'so2': 10.28, 'soot': 29.17}
# Transformed:  {'no2_normalized': -3.917978286743164, 'pm10_normalized': 0.1242293268442154, 'so2_normalized': -5.244592666625977, 'soot_normalized': 0.22793900966644287}
# Initial:  {'pm10': 38.77, 'no2': 28.01, 'so2': 10.72, 'soot': 23.17}
# Transformed:  {'no2_normalized': -4.667978286743164, 'pm10_normalized': 0.11957765370607376, 'so2_normalized': -4.804592132568359, 'soot_normalized': 0.16891293227672577}
# Initial:  {'pm10': 33.68, 'no2': 21.45, 'so2': 9.28, 'soot': 19.89}
# Transformed:  {'no2_normalized': -11.227977752685547, 'pm10_normalized': 0.10078635066747665, 'so2_normalized': -6.244592666625977, 'soot_normalized': 0.1366453468799591}
# Initial:  {'pm10': 26.18, 'no2': 18.79, 'so2': 9.35, 'soot': 16.83}
# Transformed:  {'no2_normalized': -13.887977600097656, 'pm10_normalized': 0.07309779524803162, 'so2_normalized': -6.174592018127441, 'soot_normalized': 0.10654205083847046}
# Initial:  {'pm10': 31.15, 'no2': 28.15, 'so2': 9.67, 'soot': 25.11}
# Transformed:  {'no2_normalized': -4.527978897094727, 'pm10_normalized': 0.09144608676433563, 'so2_normalized': -5.854592323303223, 'soot_normalized': 0.18799804151058197}
# Initial:  {'pm10': 32.42, 'no2': 26.43, 'so2': 11.57, 'soot': 23.28}
# Transformed:  {'no2_normalized': -6.247978210449219, 'pm10_normalized': 0.09613467007875443, 'so2_normalized': -3.954592704772949, 'soot_normalized': 0.16999508440494537}
# Initial:  {'pm10': 24.1, 'no2': 23.91, 'so2': 9.83, 'soot': 17.06}
# Transformed:  {'no2_normalized': -8.76797866821289, 'pm10_normalized': 0.06541883945465088, 'so2_normalized': -5.694592475891113, 'soot_normalized': 0.10880471765995026}
# Initial:  {'pm10': 21.87, 'no2': 24.86, 'so2': 9.44, 'soot': 25.06}
# Transformed:  {'no2_normalized': -7.8179779052734375, 'pm10_normalized': 0.05718610808253288, 'so2_normalized': -6.084592819213867, 'soot_normalized': 0.18750613927841187}
# Initial:  {'pm10': 25.8, 'no2': 24.5, 'so2': 10.49, 'soot': 19.95}
# Transformed:  {'no2_normalized': -8.177978515625, 'pm10_normalized': 0.07169490307569504, 'so2_normalized': -5.034592628479004, 'soot_normalized': 0.1372356116771698}
# Initial:  {'pm10': 15.02, 'no2': 18.2, 'so2': 9.03, 'soot': 13.16}
# Transformed:  {'no2_normalized': -14.477977752685547, 'pm10_normalized': 0.03189722076058388, 'so2_normalized': -6.494592666625977, 'soot_normalized': 0.07043777406215668}
# Initial:  {'pm10': 16.43, 'no2': 17.79, 'so2': 9.07, 'soot': 16.21}
# Transformed:  {'no2_normalized': -14.887977600097656, 'pm10_normalized': 0.03710266947746277, 'so2_normalized': -6.454592704772949, 'soot_normalized': 0.10044268518686295}
# Initial:  {'pm10': 23.88, 'no2': 25.64, 'so2': 10.05, 'soot': 21.84}
# Transformed:  {'no2_normalized': -7.0379791259765625, 'pm10_normalized': 0.06460663676261902, 'so2_normalized': -5.474592208862305, 'soot_normalized': 0.1558288186788559}
# Initial:  {'pm10': 32.32, 'no2': 28.14, 'so2': 10.79, 'soot': 23.05}
# Transformed:  {'no2_normalized': -4.5379791259765625, 'pm10_normalized': 0.09576549381017685, 'so2_normalized': -4.734592437744141, 'soot_normalized': 0.16773240268230438}
# Initial:  {'pm10': 43.03, 'no2': 27.55, 'so2': 12.89, 'soot': 28.28}
# Transformed:  {'no2_normalized': -5.127979278564453, 'pm10_normalized': 0.1353047490119934, 'so2_normalized': -2.634592056274414, 'soot_normalized': 0.21918347477912903}
# Initial:  {'pm10': 45.87, 'no2': 31.64, 'so2': 12.04, 'soot': 23.56}
# Transformed:  {'no2_normalized': -1.0379791259765625, 'pm10_normalized': 0.1457894891500473, 'so2_normalized': -3.4845924377441406, 'soot_normalized': 0.1727496236562729}
# Initial:  {'pm10': 40.35, 'no2': 27.91, 'so2': 11.48, 'soot': 19.67}
# ...
# Initial:  {'pm10': 21.2, 'no2': 33.32, 'so2': 10.04, 'soot': 14.46}
# Transformed:  {'no2_normalized': 0.6420211791992188, 'pm10_normalized': 0.05471259728074074, 'so2_normalized': -5.484592437744141, 'soot_normalized': 0.0832267552614212}
# Initial:  {'pm10': 25.2, 'no2': 35.54, 'so2': 15.39, 'soot': 14.41}
# Transformed:  {'no2_normalized': 2.8620223999023438, 'pm10_normalized': 0.06947982311248779, 'so2_normalized': -0.13459205627441406, 'soot_normalized': 0.08273487538099289}
# Initial:  {'pm10': 21.73, 'no2': 30.34, 'so2': 14.31, 'soot': 15.31}
# Transformed:  {'no2_normalized': -2.3379783630371094, 'pm10_normalized': 0.05666925013065338, 'so2_normalized': -1.2145919799804688, 'soot_normalized': 0.09158878773450851}
# Initial:  {'pm10': 19.0, 'no2': 29.7, 'so2': 11.03, 'soot': 13.63}
# Transformed:  {'no2_normalized': -2.977977752685547, 'pm10_normalized': 0.046590615063905716, 'so2_normalized': -4.494592666625977, 'soot_normalized': 0.07506148517131805}
# Initial:  {'pm10': 38.15, 'no2': 37.31, 'so2': 15.98, 'soot': 17.72}
# Transformed:  {'no2_normalized': 4.632022857666016, 'pm10_normalized': 0.117288738489151, 'so2_normalized': 0.45540714263916016, 'soot_normalized': 0.1152975782752037}
# Initial:  {'pm10': 44.1, 'no2': 39.72, 'so2': 18.52, 'soot': 16.19}
# Transformed:  {'no2_normalized': 7.042022705078125, 'pm10_normalized': 0.13925498723983765, 'so2_normalized': 2.995408058166504, 'soot_normalized': 0.10024594515562057}
# Initial:  {'pm10': 48.13, 'no2': 34.53, 'so2': 15.38, 'soot': 17.83}
# Transformed:  {'no2_normalized': 1.852020263671875, 'pm10_normalized': 0.15413297712802887, 'so2_normalized': -0.14459228515625, 'soot_normalized': 0.11637973040342331}
# Initial:  {'pm10': 80.6, 'no2': 35.09, 'so2': 15.05, 'soot': 21.1}
# Transformed:  {'no2_normalized': 2.4120216369628906, 'pm10_normalized': 0.2740059792995453, 'so2_normalized': -0.4745922088623047, 'soot_normalized': 0.1485489457845688}
# Initial:  {'pm10': 76.83, 'no2': 48.86, 'so2': 18.59, 'soot': 22.71}
# Transformed:  {'no2_normalized': 16.182022094726562, 'pm10_normalized': 0.26008787751197815, 'so2_normalized': 3.0654077529907227, 'soot_normalized': 0.16438759863376617}
# Initial:  {'pm10': 63.58, 'no2': 50.83, 'so2': 18.2, 'soot': 20.75}
# Transformed:  {'no2_normalized': 18.152023315429688, 'pm10_normalized': 0.21117141842842102, 'so2_normalized': 2.675408363342285, 'soot_normalized': 0.1451057493686676}
# Initial:  {'pm10': 76.58, 'no2': 49.24, 'so2': 17.4, 'soot': 24.63}
# Transformed:  {'no2_normalized': 16.562023162841797, 'pm10_normalized': 0.2591649293899536, 'so2_normalized': 1.8754072189331055, 'soot_normalized': 0.18327593803405762}
# Initial:  {'pm10': 48.1, 'no2': 33.23, 'so2': 16.24, 'soot': 20.34}
# Transformed:  {'no2_normalized': 0.5520210266113281, 'pm10_normalized': 0.154022216796875, 'so2_normalized': 0.7154073715209961, 'soot_normalized': 0.14107230305671692}
# Initial:  {'pm10': 41.7, 'no2': 42.15, 'so2': 12.81, 'soot': 19.26}
# Transformed:  {'no2_normalized': 9.472023010253906, 'pm10_normalized': 0.13039465248584747, 'so2_normalized': -2.7145919799804688, 'soot_normalized': 0.1304476112127304}
# Initial:  {'pm10': 39.53, 'no2': 33.64, 'so2': 10.92, 'soot': 16.76}
# Transformed:  {'no2_normalized': 0.9620208740234375, 'pm10_normalized': 0.12238342314958572, 'so2_normalized': -4.604592323303223, 'soot_normalized': 0.10585341602563858}
# Initial:  {'pm10': 43.15, 'no2': 31.27, 'so2': 7.78, 'soot': 16.78}
# Transformed:  {'no2_normalized': -1.4079780578613281, 'pm10_normalized': 0.1357477754354477, 'so2_normalized': -7.744592189788818, 'soot_normalized': 0.10605017840862274}
# Initial:  {'pm10': 37.75, 'no2': 35.07, 'so2': 9.93, 'soot': 16.31}
# Transformed:  {'no2_normalized': 2.3920211791992188, 'pm10_normalized': 0.11581201106309891, 'so2_normalized': -5.594592094421387, 'soot_normalized': 0.10142645984888077}
# Initial:  {'pm10': 48.85, 'no2': 35.01, 'so2': 10.1, 'soot': 13.81}
# Transformed:  {'no2_normalized': 2.332019805908203, 'pm10_normalized': 0.1567910760641098, 'so2_normalized': -5.424592018127441, 'soot_normalized': 0.07683227211236954}
# Initial:  {'pm10': 49.2, 'no2': 42.74, 'so2': 11.7, 'soot': 15.83}
# Transformed:  {'no2_normalized': 10.062023162841797, 'pm10_normalized': 0.1580832153558731, 'so2_normalized': -3.8245925903320312, 'soot_normalized': 0.0967043787240982}
# Initial:  {'pm10': 49.65, 'no2': 44.01, 'so2': 12.48, 'soot': 18.78}
# Transformed:  {'no2_normalized': 11.332019805908203, 'pm10_normalized': 0.159744530916214, 'so2_normalized': -3.04459285736084, 'soot_normalized': 0.12572553753852844}
# Initial:  {'pm10': 35.98, 'no2': 33.62, 'so2': 10.33, 'soot': 17.32}
# Transformed:  {'no2_normalized': 0.9420204162597656, 'pm10_normalized': 0.10927750915288925, 'so2_normalized': -5.194592475891113, 'soot_normalized': 0.1113625168800354}
# Initial:  {'pm10': 31.35, 'no2': 27.43, 'so2': 12.98, 'soot': 16.06}
# Transformed:  {'no2_normalized': -5.247978210449219, 'pm10_normalized': 0.09218444675207138, 'so2_normalized': -2.54459285736084, 'soot_normalized': 0.0989670380949974}
# Initial:  {'pm10': 37.8, 'no2': 28.23, 'so2': 10.92, 'soot': 13.54}
# Transformed:  {'no2_normalized': -4.447978973388672, 'pm10_normalized': 0.1159965991973877, 'so2_normalized': -4.604592323303223, 'soot_normalized': 0.07417609542608261}
# Initial:  {'pm10': 32.88, 'no2': 34.86, 'so2': 11.08, 'soot': 10.47}
# Transformed:  {'no2_normalized': 2.1820220947265625, 'pm10_normalized': 0.09783291071653366, 'so2_normalized': -4.444592475891113, 'soot_normalized': 0.04397442564368248}
# Initial:  {'pm10': 30.68, 'no2': 27.07, 'so2': 9.95, 'soot': 11.03}
# Transformed:  {'no2_normalized': -5.607978820800781, 'pm10_normalized': 0.08971092849969864, 'so2_normalized': -5.574592590332031, 'soot_normalized': 0.0494835190474987}
# Initial:  {'pm10': 27.85, 'no2': 23.1, 'so2': 12.35, 'soot': 11.38}
# Transformed:  {'no2_normalized': -9.577978134155273, 'pm10_normalized': 0.0792631208896637, 'so2_normalized': -3.1745920181274414, 'soot_normalized': 0.05292670801281929}
# Initial:  {'pm10': 32.95, 'no2': 27.42, 'so2': 12.55, 'soot': 11.92}
# Transformed:  {'no2_normalized': -5.257978439331055, 'pm10_normalized': 0.09809133410453796, 'so2_normalized': -2.9745922088623047, 'soot_normalized': 0.058239053934812546}
# Initial:  {'pm10': 22.08, 'no2': 30.36, 'so2': 12.02, 'soot': 10.5}
# Transformed:  {'no2_normalized': -2.3179779052734375, 'pm10_normalized': 0.05796138569712639, 'so2_normalized': -3.504591941833496, 'soot_normalized': 0.04426955059170723}
# Initial:  {'pm10': 32.73, 'no2': 35.57, 'so2': 14.79, 'soot': 12.7}
# Transformed:  {'no2_normalized': 2.8920211791992188, 'pm10_normalized': 0.0972791314125061, 'so2_normalized': -0.7345924377441406, 'soot_normalized': 0.06591244041919708}
# Initial:  {'pm10': 28.98, 'no2': 30.92, 'so2': 14.07, 'soot': 13.15}
# Transformed:  {'no2_normalized': -1.7579784393310547, 'pm10_normalized': 0.08343485742807388, 'so2_normalized': -1.4545927047729492, 'soot_normalized': 0.0703393965959549}
# Initial:  {'pm10': 42.05, 'no2': 34.51, 'so2': 15.36, 'soot': 13.18}
# Transformed:  {'no2_normalized': 1.8320198059082031, 'pm10_normalized': 0.13168677687644958, 'so2_normalized': -0.16459274291992188, 'soot_normalized': 0.07063452899456024}
# Initial:  {'pm10': 58.78, 'no2': 45.75, 'so2': 14.98, 'soot': 22.3}
# Transformed:  {'no2_normalized': 13.072021484375, 'pm10_normalized': 0.19345073401927948, 'so2_normalized': -0.5445928573608398, 'soot_normalized': 0.1603541523218155}
# Initial:  {'pm10': 63.48, 'no2': 51.06, 'so2': 15.23, 'soot': 25.33}
# Transformed:  {'no2_normalized': 18.382022857666016, 'pm10_normalized': 0.21080222725868225, 'so2_normalized': -0.29459285736083984, 'soot_normalized': 0.1901623159646988}
# Initial:  {'pm10': 57.1, 'no2': 42.83, 'so2': 15.44, 'soot': 27.76}
# Transformed:  {'no2_normalized': 10.152023315429688, 'pm10_normalized': 0.18724848330020905, 'so2_normalized': -0.08459281921386719, 'soot_normalized': 0.21406787633895874}
# Initial:  {'pm10': 34.05, 'no2': 38.46, 'so2': 13.78, 'soot': 19.68}
# Transformed:  {'no2_normalized': 5.782020568847656, 'pm10_normalized': 0.10215231776237488, 'so2_normalized': -1.7445926666259766, 'soot_normalized': 0.13457943499088287}
# Initial:  {'pm10': 36.8, 'no2': 40.8, 'so2': 13.79, 'soot': 18.8}
# Transformed:  {'no2_normalized': 8.122020721435547, 'pm10_normalized': 0.11230479180812836, 'so2_normalized': -1.7345924377441406, 'soot_normalized': 0.1259222775697708}
# Initial:  {'pm10': 35.15, 'no2': 34.6, 'so2': 12.44, 'soot': 18.1}
# Transformed:  {'no2_normalized': 1.9220199584960938, 'pm10_normalized': 0.10621331632137299, 'so2_normalized': -3.084592819213867, 'soot_normalized': 0.11903590708971024}
# Initial:  {'pm10': 49.28, 'no2': 39.76, 'so2': 16.46, 'soot': 18.62}
# Transformed:  {'no2_normalized': 7.082019805908203, 'pm10_normalized': 0.15837855637073517, 'so2_normalized': 0.9354066848754883, 'soot_normalized': 0.12415150552988052}
# Initial:  {'pm10': 66.23, 'no2': 38.92, 'so2': 15.99, 'soot': 24.0}
# Transformed:  {'no2_normalized': 6.2420196533203125, 'pm10_normalized': 0.22095471620559692, 'so2_normalized': 0.4654073715209961, 'soot_normalized': 0.17707820236682892}
# Initial:  {'pm10': 51.9, 'no2': 29.95, 'so2': 12.58, 'soot': 17.11}
# Transformed:  {'no2_normalized': -2.727977752685547, 'pm10_normalized': 0.1680510938167572, 'so2_normalized': -2.9445924758911133, 'soot_normalized': 0.10929661244153976}
# Initial:  {'pm10': 41.4, 'no2': 20.78, 'so2': 16.75, 'soot': 16.29}
# Transformed:  {'no2_normalized': -11.897977828979492, 'pm10_normalized': 0.12928710877895355, 'so2_normalized': 1.225407600402832, 'soot_normalized': 0.1012297198176384}
# Initial:  {'pm10': 26.83, 'no2': 26.44, 'so2': 15.29, 'soot': 11.27}
# Transformed:  {'no2_normalized': -6.237977981567383, 'pm10_normalized': 0.07549747824668884, 'so2_normalized': -0.23459243774414062, 'soot_normalized': 0.05184456706047058}
# Initial:  {'pm10': 22.47, 'no2': 26.38, 'so2': 16.08, 'soot': 8.19}
# Transformed:  {'no2_normalized': -6.297979354858398, 'pm10_normalized': 0.059401191771030426, 'so2_normalized': 0.5554075241088867, 'soot_normalized': 0.02154451049864292}
# Initial:  {'pm10': 17.87, 'no2': 27.9, 'so2': 16.79, 'soot': 9.55}
# Transformed:  {'no2_normalized': -4.777978897094727, 'pm10_normalized': 0.04241887480020523, 'so2_normalized': 1.2654085159301758, 'soot_normalized': 0.03492375835776329}
# Initial:  {'pm10': 21.73, 'no2': 27.23, 'so2': 18.79, 'soot': 8.49}
# Transformed:  {'no2_normalized': -5.447978973388672, 'pm10_normalized': 0.05666925013065338, 'so2_normalized': 3.265408515930176, 'soot_normalized': 0.024495815858244896}
# Initial:  {'pm10': 22.07, 'no2': 27.29, 'so2': 14.36, 'soot': 11.04}
# Transformed:  {'no2_normalized': -5.387977600097656, 'pm10_normalized': 0.05792446434497833, 'so2_normalized': -1.1645927429199219, 'soot_normalized': 0.049581896513700485}
# Initial:  {'pm10': 53.3, 'no2': 34.32, 'so2': 15.87, 'soot': 12.51}
# Transformed:  {'no2_normalized': 1.6420211791992188, 'pm10_normalized': 0.17321962118148804, 'so2_normalized': 0.34540748596191406, 'soot_normalized': 0.06404328346252441}
# Initial:  {'pm10': 72.27, 'no2': 32.79, 'so2': 19.79, 'soot': 14.8}
# Transformed:  {'no2_normalized': 0.11202239990234375, 'pm10_normalized': 0.2432532161474228, 'so2_normalized': 4.265408515930176, 'soot_normalized': 0.08657156676054001}
# Initial:  {'pm10': 35.07, 'no2': 25.75, 'so2': 15.19, 'soot': 12.5}
# Transformed:  {'no2_normalized': -6.927978515625, 'pm10_normalized': 0.10591796785593033, 'so2_normalized': -0.3345928192138672, 'soot_normalized': 0.06394490599632263}
# Initial:  {'pm10': 30.7, 'no2': 33.26, 'so2': 14.51, 'soot': 14.18}
# Transformed:  {'no2_normalized': 0.5820198059082031, 'pm10_normalized': 0.08978477120399475, 'so2_normalized': -1.014592170715332, 'soot_normalized': 0.08047220855951309}
# Initial:  {'pm10': 59.2, 'no2': 37.4, 'so2': 27.18, 'soot': 20.77}
# Transformed:  {'no2_normalized': 4.722023010253906, 'pm10_normalized': 0.1950012892484665, 'so2_normalized': 11.655407905578613, 'soot_normalized': 0.14530250430107117}
# Initial:  {'pm10': 89.33, 'no2': 47.61, 'so2': 23.2, 'soot': 25.04}
# Transformed:  {'no2_normalized': 14.932022094726562, 'pm10_normalized': 0.30623549222946167, 'so2_normalized': 7.675408363342285, 'soot_normalized': 0.1873093992471695}
# Initial:  {'pm10': 78.7, 'no2': 55.61, 'so2': 21.38, 'soot': 27.87}
# Transformed:  {'no2_normalized': 22.932022094726562, 'pm10_normalized': 0.2669915556907654, 'so2_normalized': 5.855406761169434, 'soot_normalized': 0.21515002846717834}
# Initial:  {'pm10': 177.1, 'no2': 85.79, 'so2': 23.24, 'soot': 36.75}
# Transformed:  {'no2_normalized': 53.112022399902344, 'pm10_normalized': 0.630265474319458, 'so2_normalized': 7.715407371520996, 'soot_normalized': 0.3025085926055908}
# Initial:  {'pm10': 190.23, 'no2': 89.32, 'so2': 25.1, 'soot': 34.97}
# Transformed:  {'no2_normalized': 56.64202117919922, 'pm10_normalized': 0.6787388324737549, 'so2_normalized': 9.575407981872559, 'soot_normalized': 0.2849975526332855}
# Initial:  {'pm10': 142.83, 'no2': 58.59, 'so2': 21.36, 'soot': 23.35}
# Transformed:  {'no2_normalized': 25.91202163696289, 'pm10_normalized': 0.5037471652030945, 'so2_normalized': 5.8354082107543945, 'soot_normalized': 0.17068372666835785}
# Initial:  {'pm10': 88.77, 'no2': 42.78, 'so2': 19.86, 'soot': 23.85}
# Transformed:  {'no2_normalized': 10.102020263671875, 'pm10_normalized': 0.30416804552078247, 'so2_normalized': 4.3354082107543945, 'soot_normalized': 0.17560255527496338}
# Initial:  {'pm10': 63.73, 'no2': 52.96, 'so2': 19.28, 'soot': 26.09}
# Transformed:  {'no2_normalized': 20.282020568847656, 'pm10_normalized': 0.2117251753807068, 'so2_normalized': 3.75540828704834, 'soot_normalized': 0.19763895869255066}
# Initial:  {'pm10': 114.83, 'no2': 82.11, 'so2': 25.87, 'soot': 29.71}
# Transformed:  {'no2_normalized': 49.43202209472656, 'pm10_normalized': 0.4003765881061554, 'so2_normalized': 10.34540843963623, 'soot_normalized': 0.23325133323669434}
# Initial:  {'pm10': 75.4, 'no2': 61.62, 'so2': 20.27, 'soot': 24.95}
# Transformed:  {'no2_normalized': 28.942020416259766, 'pm10_normalized': 0.25480860471725464, 'so2_normalized': 4.745408058166504, 'soot_normalized': 0.18642400205135345}
# Initial:  {'pm10': 67.47, 'no2': 39.94, 'so2': 19.6, 'soot': 19.67}
# Transformed:  {'no2_normalized': 7.262020111083984, 'pm10_normalized': 0.22553254663944244, 'so2_normalized': 4.075407981872559, 'soot_normalized': 0.1344810575246811}
# Initial:  {'pm10': 62.93, 'no2': 71.05, 'so2': 25.36, 'soot': 19.86}
# Transformed:  {'no2_normalized': 38.37202453613281, 'pm10_normalized': 0.2087717354297638, 'so2_normalized': 9.835408210754395, 'soot_normalized': 0.13635022938251495}
# Initial:  {'pm10': 114.03, 'no2': 86.51, 'so2': 30.76, 'soot': 29.9}
# Transformed:  {'no2_normalized': 53.83202362060547, 'pm10_normalized': 0.39742311835289, 'so2_normalized': 15.235407829284668, 'soot_normalized': 0.2351205050945282}
# Initial:  {'pm10': 178.07, 'no2': 106.03, 'so2': 33.76, 'soot': 43.22}
# Transformed:  {'no2_normalized': 73.35202026367188, 'pm10_normalized': 0.6338465213775635, 'so2_normalized': 18.23540496826172, 'soot_normalized': 0.3661583960056305}
# Initial:  {'pm10': 98.0, 'no2': 82.28, 'so2': 27.73, 'soot': 31.5}
# Transformed:  {'no2_normalized': 49.602020263671875, 'pm10_normalized': 0.3382434546947479, 'so2_normalized': 12.20540714263916, 'soot_normalized': 0.2508607804775238}
# Initial:  {'pm10': 24.07, 'no2': 44.24, 'so2': 15.76, 'soot': 16.46}
# Transformed:  {'no2_normalized': 11.562023162841797, 'pm10_normalized': 0.06530807912349701, 'so2_normalized': 0.23540782928466797, 'soot_normalized': 0.10290210694074631}
# Initial:  {'pm10': 24.03, 'no2': 42.27, 'so2': 18.57, 'soot': 14.21}
# Transformed:  {'no2_normalized': 9.592021942138672, 'pm10_normalized': 0.06516041606664658, 'so2_normalized': 3.045407295227051, 'soot_normalized': 0.08076734095811844}
# Initial:  {'pm10': 47.97, 'no2': 31.57, 'so2': 15.66, 'soot': 14.01}
# Transformed:  {'no2_normalized': -1.1079788208007812, 'pm10_normalized': 0.15354229509830475, 'so2_normalized': 0.1354074478149414, 'soot_normalized': 0.07879980653524399}
